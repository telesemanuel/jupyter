# %% [markdown]
# # Titulo nivel 1
#
# # Titulo nivel 2
#
# # Titulo nivel 3
#
# *Itálico*<br />
# **Negrito**<br />
# ***Negrito Itálico***<br />
#
# Este e um texto normal!
#
# Exemplo de um código *hello world* no *markdown*:<br />
# `print("Hello World)`.
# <br />
# <br />
# 1. Você vai clicar em **Não**?<br /><br />
# <input type="radio" name="questão"><span>Sim</span><br />
# <input type="radio" name="questão"><span>Não</span><br />
# <br />
# 2. Informe suas hbilidades:<br /><br />
# <input type="radio" name="checkbox" name="hab" /> Operador Micro<br />
# <input type="radio" name="checkbox" name="hab" /> HTML<br />
# <input type="radio" name="checkbox" name="hab" /> Java<br />
# <input type="radio" name="checkbox" name="hab" /> Python<br />
#
# ### Tópicos
#
# - Tópico 1
# - Tópico 2
# - Tópico 3
#
# ### Numeração
#
# 1. Numeração 1
# 2. Numeração 2
# 3. Numeração 3

# %% [markdown]
# ## TRABALHANDO CODIGOS EM JUPYTER
#
# abaixo segue um codigo funcional em *Python* rodando em *notebok*

# %%
n1 = 15
n2 = 5
n3 = n1+n2

print(f"Qual nome do filme?\nResposta = O Código dá {n3}")
# Out:
# Qual nome do filme?
# Resposta = O Código dá 20

# %% [markdown]
# Repare que o codigo-fonte das células consideram o resultado das células anteriores do mesmo notebook.
# Observe no código a seguir:

# %%
x = 10

print(f"Resultado = {x*n3}")
# Out:
# Resultado = 200

# %% [markdown]
# Vamos ver como um código de entrada de dados se comporta em um notebook:

# %%
texto = input("Informe um texto a ser exibido na célula: ")
print(texto)
# Out:
# dghfgh

# %% [markdown]
# Imagem no Markdown:

# %% [markdown]
# ![image.png](attachment:image.png)
